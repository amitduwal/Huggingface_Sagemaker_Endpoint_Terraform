# %%
# !pip install PyMuPDF
# !pip install langchain
# !pip install InstructorEmbedding
# !pip install sentence_transformers

# %%
import fitz
from langchain.text_splitter import CharacterTextSplitter

# %%
def get_pdf_text_pymupdf(input_pdf_path):
    text = ""
    pdf_document = fitz.open(input_pdf_path)
    for page_number in range(pdf_document.page_count):
        page = pdf_document.load_page(page_number)
        text += page.get_text()
    pdf_document.close()
    return text

# %%
test_doc = "/content/drive/MyDrive/Embeddings/Human Resource Directives.pdf"
text = get_pdf_text_pymupdf(test_doc)

# %%
text_splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size = 1500,
    chunk_overlap  = 40
)
chunks = text_splitter.split_text(text)

# %%
print(len(chunks))
for chunk in chunks:
  print(str(len(chunk)))
# Out:
# 10
# 1446
# 1495
# 1492
# 1479
# 1423
# 1452
# 1494
# 1480
# 1471
# 1320

# %%
from InstructorEmbedding import INSTRUCTOR
from sentence_transformers import SentenceTransformer
model = INSTRUCTOR('hkunlp/instructor-large')
# Out:
# /usr/local/lib/python3.10/dist-packages/InstructorEmbedding/instructor.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
# %%time
embeddings_a = model.encode(chunks)
# Out:
# CPU times: user 44.4 s, sys: 1.11 s, total: 45.5 s
# Wall time: 48 s

# %%
from InstructorEmbedding import INSTRUCTOR
from sentence_transformers import SentenceTransformer
model1 = INSTRUCTOR('hkunlp/instructor-xl')
# Out:
# /usr/local/lib/python3.10/dist-packages/InstructorEmbedding/instructor.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
# %%time
embeddings_b = model1.encode(chunks)
# Out:
# CPU times: user 2min 54s, sys: 10.1 ms, total: 2min 54s
# Wall time: 2min 56s

# %%
sentences = ["The quick brown fox jumps over the lazy dog, testing its agility and cunning instincts.","In the distant cosmos, stars twinkle like distant dreams, painting the night sky with their cosmic ballet.","Lost in the labyrinthine corridors, the intrepid explorer seeks the ancient treasure buried in darkness.","Amidst the raging storm, the sailor battles the relentless waves, hoping to reach the distant shore","Beneath the gnarled oak tree, secrets of the past are whispered by the rustling leaves.","Through the kaleidoscope of life's experiences, we find the beauty in every color and hue.","In the realm of imagination, fantastical creatures come alive, dancing with the muse's inspiration","As the clock's pendulum swings, time weaves stories of beginnings and farewells in its wake.","Upon the summit's edge, a breathtaking panorama unveils nature's grandeur in all its splendor","With every beat of the heart, a symphony of life resonates, embracing the journey's melodies."]

# %%
# %%time
embeddings_c = model.encode(sentences)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'model' is not defined

# %%
# %%time
embeddings_c = model1.encode(sentences)
# Out:
# CPU times: user 18.5 s, sys: 0 ns, total: 18.5 s
# Wall time: 18.6 s

# %%
paragraphs = ["Once a candidate has been selected, the HR department will prepare an offer letter that outlines the terms of the job offer, including salary, benefits, and any other relevant details. The offer letter should be clear and concise, and should provide the candidate with a deadline for accepting the offer","Once the candidate has accepted the offer, the HR department will develop an onboarding plan that outlines the steps that will be taken to prepare the candidate for their new role. This could include training on company policies and procedures, introductions to team members, and an overview of the company culture and values.","The HR department will work with the hiring manager to establish key performance indicators (KPIs) and goals for the new employee. This could include specific objectives to be achieved within the first 30, 60, and 90 days, as well as longer-term goals. The hiring manager will conduct regular check-ins with the new employee.","The HR department will coordinate performance reviews for the new employee at regular intervals, such as every 6 months or annually. These reviews will provide the employee with feedback on their performance and help them to identify areas for improvement. The hiring manager and HR department will work together to provide coaching","The HR department will work with IT and other departments to ensure that the candidate has the necessary equipment and software to perform their job. This could include a laptop, phone, and any specialized software that is required. The HR department will prepare new hire paperwork, such as tax forms and benefit enrollment forms.","The purpose of this SOP is to provide guidelines and instructions to all PMO office personnel to ensure consistency, accuracy, and efficiency in project management practices. The SOP outlines the best practices for managing projects and resources, and for ensuring consistent and efficient communication with clients. ","In addition to outlining the standard practices that will be followed by the PMO office, this SOP emphasizes the importance of collaboration and communication among team members and with clients. By following the guidelines outlined in this SOP, the PMO office can ensure that projects are completed to the highest standards.","It is expected that all PMO office personnel will follow the procedures and guidelines outlined in this SOP to ensure that all projects are managed in a consistent manner. The PMO office will also continuously review and improve its processes to ensure that they are aligned with the needs of the company.","The first step in managing a project is project initiation, which is the process of defining the project's scope, timeline, and budget. The goal of project initiation is to establish a clear understanding of the project's objectives, stakeholders, and constraints, and to develop a plan for how the project will be executed","Identify Project Stakeholders: The PMO office will identify the key stakeholders who are involved in the project and establish a communication plan to ensure that stakeholders are kept informed of project progress. The communication plan should include the frequency, format, and content of project status reports."]

# %%
# %%time
embeddings_p = model.encode(paragraphs)
# Out:
# CPU times: user 8.68 s, sys: 24.7 ms, total: 8.71 s
# Wall time: 8.73 s

# %%
# %%time
embeddings_c = model1.encode(paragraphs)
# Out:
# CPU times: user 35.5 s, sys: 1.48 s, total: 37 s
# Wall time: 37.3 s
